# %% [markdown]
# # IndoxMiner-Object Detection
#
# Welcome to the IndoxMiner object detection demo! In this notebook, we will demonstrate how to use various pre-trained object detection models provided by IndoxMiner to detect objects in images.
#
# The available models include:
# - **DETR**
# - **YOLOv5, YOLOv6, YOLOv7, YOLOv8, YOLOv10, YOLOv11**
# - **Detectron2**
# - **GroundingDINO**
# - **RTDETR**
# - **Kosmos2**
# - **OWLVit**
# - **SAM2**
# - **DETRCLIP**
#
# Don't worry about installing or setting up models manually — IndoxMiner handles all dependencies and installation for you automatically.

# %% [markdown]
# ### **Install IndoxMiner and Dependencies**

# %%
# Install IndoxMiner (If not already installed)
# !pip install indoxminer
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.7/161.7 kB 5.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.6/45.6 MB 12.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 981.5/981.5 kB 37.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 3.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.0/42.0 kB 3.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.4/149.4 kB 11.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 7.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 56.7 MB/s eta 0:00:00
# ...

# %% [markdown]
# ### **Import Libraries**

# %%
# Import necessary libraries
from indoxMiner.detection import DETR, YOLOv11, Detectron2, GroundingDINO
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# ### **Model Initialization**
#
# ## Step 1: Initialize the Object Detection Models
#
# In this example, we will initialize the **DETR** and **YOLOv11** models, which are among the most popular object detection models available in IndoxMiner.
#
# We will use the default configurations, and the models will automatically download any necessary weights or checkpoints if they aren't already available.

# %%
# Initialize the DETR model
detr_model = DETR()

# Initialize the YOLOv11 model
# yolov11_model = YOLOv11("yolo11n")
# Out:
# Some weights of the model checkpoint at facebook/detr-resnet-50 were not used when initializing DetrForObjectDetection: ['model.backbone.conv_encoder.model.layer1.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer2.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer3.0.downsample.1.num_batches_tracked', 'model.backbone.conv_encoder.model.layer4.0.downsample.1.num_batches_tracked']
# - This IS expected if you are initializing DetrForObjectDetection from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DetrForObjectDetection from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %% [markdown]
# ### **Load an Image**
#
#
# ## Step 2: Load an Image for Object Detection
#
# Next, we will load an image for object detection. This image can be from any source, and for this demo, we are using a sample image of a dog and a cat.
#
# The models will predict the objects in the image and output bounding boxes with labels.

# %%
# Load an image using PIL
image_path = "/content/dog-cat-under-sheet.jpg"  # Replace with the actual image path
image = Image.open(image_path)

# Display the image
plt.imshow(image)
plt.axis('off')  # Hide axes
plt.show()

# %% [markdown]
# ### **Perform Object Detection with DETR**
#
#
# ## Step 3: Perform Object Detection with DETR
#
# We will use the **DETR** model to detect objects in the image. The model will return a list of objects detected in the image, including their class labels and bounding boxes.

# %%
# Run object detection with DETR
detr_outputs = detr_model.detect_objects(image_path=image_path)

# Visualize the results with DETR
detr_model.visualize_results(detr_outputs)

# %% [markdown]
# ### **Perform Object Detection with YOLOv11**
#
#
# ## Step 4: Perform Object Detection with YOLOv11
#
# Now, we will use the **YOLOv11** model, which is another popular and fast object detection model. YOLOv11 provides high accuracy and speed for real-time applications.

# %%
# Run object detection with YOLOv11
yolov11_outputs = yolov11_model.detect_objects(image_path=image_path)

# Visualize the results with YOLOv11
yolov11_model.visualize_results(yolov11_outputs)

# %% [markdown]
# ### **Comparison of Results**
#
# ## Step 5: Comparison of Results
#
# We have performed object detection on the same image using **DETR** and **YOLOv11**. Each model provides bounding boxes and class labels for the detected objects.
#
# While the results might look similar, different models may perform better for certain tasks based on factors like speed, accuracy, and specific domain requirements.
#
# You can choose the best model for your use case based on these considerations.
#
#
# ---
#
# # Conclusion
#
# In this demo, we've shown how to use **IndoxMiner** to perform object detection using popular models like **DETR** and **YOLOv11**. The IndoxMiner library simplifies the process of setting up object detection models by handling dependencies and weights automatically, so you can focus on solving your problem.
#
# We hope this demonstration helps you get started with object detection using IndoxMiner. Feel free to explore more models and configurations to suit your needs!
#
# Happy coding!
#
#
# ---
#
# ### **Summary of the Jupyter Notebook:**
#
# 1. **Introduction**: Explains what the notebook does and provides an overview of the available models.
# 2. **Installation**: Ensures that the required library, **IndoxMiner**, is installed.
# 3. **Model Initialization**: Demonstrates how to initialize models like **DETR** and **YOLOv11**.
# 4. **Image Loading**: Loads an image for processing.
# 5. **Object Detection**: Runs object detection using the models.
# 6. **Visualization**: Displays the detection results with bounding boxes on the image.
# 7. **Comparison**: Provides a brief comparison of the results from different models.
# 8. **Conclusion**: Summarizes the demo and encourages exploration.
#
# This format helps users understand how to use the library in a clear, step-by-step manner, and it can easily be adapted for other models in the **IndoxMiner** library. Let me know if you'd like to add or adjust any steps!
